# %%
import pykeen
from pykeen.pipeline import pipeline
from pykeen.datasets import get_dataset

# %%
import pykeen
pykeen.env()
# Out:
# <table>
# <thead>
# <tr><th>Key            </th><th>Value                   </th></tr>
# </thead>
# <tbody>
# <tr><td>OS             </td><td>posix                   </td></tr>
# <tr><td>Platform       </td><td>Linux                   </td></tr>
# <tr><td>Release        </td><td>6.5.0-41-generic        </td></tr>
# <tr><td>Time           </td><td>Wed Jun 19 21:14:10 2024</td></tr>
# <tr><td>Python         </td><td>3.12.4                  </td></tr>
# <tr><td>PyKEEN         </td><td>1.10.2                  </td></tr>
# <tr><td>PyKEEN Hash    </td><td>aa183023                </td></tr>
# <tr><td>PyKEEN Branch  </td><td>master                  </td></tr>
# <tr><td>PyTorch        </td><td>2.3.1+cu121             </td></tr>
# <tr><td>CUDA Available?</td><td>true                    </td></tr>
# <tr><td>CUDA Version   </td><td>12.1                    </td></tr>
# <tr><td>cuDNN Version  </td><td>8902                    </td></tr>
# </tbody>
# </table>

# %%
dataset = get_dataset(dataset="hetionet")

# %%
dataset.num_entities
# Out:
# 45158

# %%
dataset.num_relations
# Out:
# 24

# %%
# Run transe model with baseline parameters
def run_baseline(config: dict):

    pipeline_result = pipeline(
        dataset=config["dataset"],
        dataset_kwargs={
            "random_state": config["seed"],
            "create_inverse_triples": config["train"]["create_inverse"],
        },
        model=config["model"]["name"],
        model_kwargs={
            "embedding_dim": config["model"]["embedding_dim"],
            "random_seed": config["seed"],
        },
        training_loop="sLCWA",
        training_kwargs={
            "num_epochs": config["train"]["num_epoch"],
        },
        optimizer=config["optimizer"]["class"],
        optimizer_kwargs={"lr": config["optimizer"]["lr"]},
        negative_sampler_kwargs={
            "num_negs_per_pos": config["train"]["num_negative"],
        },
        evaluation_relation_whitelist = set(ctd_config['train']['evaluation_relation_whitelist']),
        stopper='early',
        stopper_kwargs=dict(frequency=10, patience=3, relative_delta=0.002),
        random_seed=config["seed"],
        evaluator_kwargs={"filtered": True},
        use_testing_data=False,
        result_tracker='mlflow',
        result_tracker_kwargs=dict(
        tracking_uri='http://localhost:5000',
        experiment_name=config["experiment_name"],
    ),
    )
    
    pipeline_result.save_to_directory(config["save"]["path"])
    return pipeline_result


import yaml


def load_config(config_path: str) -> dict:
    """Load a YAML config file"""

    with open(config_path, "r", encoding="utf-8") as file:
        config = yaml.safe_load(file)

    return config

run_config: dict = load_config('config/transe.yaml')

# %%
def print_metrics(metric_results):
    print("MRR: {}".format(metric_results.get_metric("inverseharmonicmeanrank")))
    print("Hits@1: {}".format(metric_results.get_metric("hits_at_1")))
    print("Hits@3: {}".format(metric_results.get_metric("hits_at_3")))
    print("Hits@10: {}".format(metric_results.get_metric("hits_at_10")))

# %%
# result_ep100 = run_baseline(run_config)

model_ep100 = torch.load('results/baseline/transe_hetionet_ep100/trained_model.pkl')

# %%
# print_metrics(result_ep100.metric_results)

# %%
from pykeen.predict import predict_all
pack_ep100_all = predict_all(model=model_ep100, k=50)
# Out:
# WARNING:pykeen.predict:predict is an expensive operation, involving 48,941,879,136 score evaluations.

# %%
df_ep100_all = pack_ep100_all.process(factory=dataset.training).df

df_ep100_all.nlargest(n=50, columns="score")
# Out:
#     head_id               head_label  relation_id relation_label  tail_id  \
# 0        59  Anatomy::UBERON:0001016           14            DrD       10
# 1     30068               Gene::7415            7            CrC    22231
# 2     38131        Pathway::PC7_7457            7            CrC    37454
# 3        29  Anatomy::UBERON:0000948           14            DrD      279
# 28       65  Anatomy::UBERON:0001064            7            CrC       65
# 29       66  Anatomy::UBERON:0001067            7            CrC       66
# 30       67  Anatomy::UBERON:0001070            7            CrC       67
# 31       69  Anatomy::UBERON:0001088            7            CrC       69
# 32       75  Anatomy::UBERON:0001111            7            CrC       75
# 33       78  Anatomy::UBERON:0001135            7            CrC       78
# 34       79  Anatomy::UBERON:0001140            7            CrC       79
# 35       80  Anatomy::UBERON:0001143            7            CrC       80
# 36       81  Anatomy::UBERON:0001148            7            CrC       81
# 37       82  Anatomy::UBERON:0001174            7            CrC       82
# 38       83  Anatomy::UBERON:0001175            7            CrC       83
# 27       64  Anatomy::UBERON:0001044            7            CrC       64
# 40       87  Anatomy::UBERON:0001193            7            CrC       87
# 41       89  Anatomy::UBERON:0001224            7            CrC       89
# 42       92  Anatomy::UBERON:0001231            7            CrC       92
# 43       93  Anatomy::UBERON:0001232            7            CrC       93
# 44       94  Anatomy::UBERON:0001235            7            CrC       94
# 45       95  Anatomy::UBERON:0001236            7            CrC       95
# 46       96  Anatomy::UBERON:0001237            7            CrC       96
# 47       98  Anatomy::UBERON:0001267            7            CrC       98
# 48       99  Anatomy::UBERON:0001283            7            CrC       99
# 39       86  Anatomy::UBERON:0001184            7            CrC       86
# 25       57  Anatomy::UBERON:0001011            7            CrC       57
# 26       61  Anatomy::UBERON:0001021            7            CrC       61
# 13       30  Anatomy::UBERON:0000949            7            CrC       30
# 4         5  Anatomy::UBERON:0000011            7            CrC        5
# 5         6  Anatomy::UBERON:0000013            7            CrC        6
# 6         7  Anatomy::UBERON:0000020            7            CrC        7
# 7         9  Anatomy::UBERON:0000029            7            CrC        9
# 8        12  Anatomy::UBERON:0000042            7            CrC       12
# 9        18  Anatomy::UBERON:0000057            7            CrC       18
# 10       20  Anatomy::UBERON:0000178            7            CrC       20
# 11       21  Anatomy::UBERON:0000211            7            CrC       21
# 12       22  Anatomy::UBERON:0000473            7            CrC       22
# 14       34  Anatomy::UBERON:0000966            7            CrC       34
# 24       54  Anatomy::UBERON:0001004            7            CrC       54
# 15       35  Anatomy::UBERON:0000970            7            CrC       35
# 16       37  Anatomy::UBERON:0000975            7            CrC       37
# 17       39  Anatomy::UBERON:0000978            7            CrC       39
# 18       40  Anatomy::UBERON:0000982            7            CrC       40
# 19       41  Anatomy::UBERON:0000985            7            CrC       41
# 20       42  Anatomy::UBERON:0000988            7            CrC       42
# 21       45  Anatomy::UBERON:0000992            7            CrC       45
# 22       50  Anatomy::UBERON:0000998            7            CrC       50
# 23       51  Anatomy::UBERON:0000999            7            CrC       51
# 49      100  Anatomy::UBERON:0001285            7            CrC      100
#
#                  tail_label     score
# 0   Anatomy::UBERON:0000033 -3.015952
# 1                Gene::3065 -3.092649
# 2         Pathway::PC7_4043 -3.134512
# 3   Anatomy::UBERON:0002048 -3.155090
# 28  Anatomy::UBERON:0001064 -3.163475
# 29  Anatomy::UBERON:0001067 -3.163475
# 30  Anatomy::UBERON:0001070 -3.163475
# 31  Anatomy::UBERON:0001088 -3.163475
# 32  Anatomy::UBERON:0001111 -3.163475
# 33  Anatomy::UBERON:0001135 -3.163475
# 34  Anatomy::UBERON:0001140 -3.163475
# 35  Anatomy::UBERON:0001143 -3.163475
# 36  Anatomy::UBERON:0001148 -3.163475
# 37  Anatomy::UBERON:0001174 -3.163475
# 38  Anatomy::UBERON:0001175 -3.163475
# 27  Anatomy::UBERON:0001044 -3.163475
# 40  Anatomy::UBERON:0001193 -3.163475
# 41  Anatomy::UBERON:0001224 -3.163475
# 42  Anatomy::UBERON:0001231 -3.163475
# 43  Anatomy::UBERON:0001232 -3.163475
# 44  Anatomy::UBERON:0001235 -3.163475
# 45  Anatomy::UBERON:0001236 -3.163475
# 46  Anatomy::UBERON:0001237 -3.163475
# 47  Anatomy::UBERON:0001267 -3.163475
# 48  Anatomy::UBERON:0001283 -3.163475
# 39  Anatomy::UBERON:0001184 -3.163475
# 25  Anatomy::UBERON:0001011 -3.163475
# 26  Anatomy::UBERON:0001021 -3.163475
# 13  Anatomy::UBERON:0000949 -3.163475
# 4   Anatomy::UBERON:0000011 -3.163475
# 5   Anatomy::UBERON:0000013 -3.163475
# 6   Anatomy::UBERON:0000020 -3.163475
# 7   Anatomy::UBERON:0000029 -3.163475
# 8   Anatomy::UBERON:0000042 -3.163475
# 9   Anatomy::UBERON:0000057 -3.163475
# 10  Anatomy::UBERON:0000178 -3.163475
# 11  Anatomy::UBERON:0000211 -3.163475
# 12  Anatomy::UBERON:0000473 -3.163475
# 14  Anatomy::UBERON:0000966 -3.163475
# 24  Anatomy::UBERON:0001004 -3.163475
# 15  Anatomy::UBERON:0000970 -3.163475
# 16  Anatomy::UBERON:0000975 -3.163475
# 17  Anatomy::UBERON:0000978 -3.163475
# 18  Anatomy::UBERON:0000982 -3.163475
# 19  Anatomy::UBERON:0000985 -3.163475
# 20  Anatomy::UBERON:0000988 -3.163475
# 21  Anatomy::UBERON:0000992 -3.163475
# 22  Anatomy::UBERON:0000998 -3.163475
# 23  Anatomy::UBERON:0000999 -3.163475
# 49  Anatomy::UBERON:0001285 -3.163475

# %%
pack_ep100 = predict_triples(model=model_ep100, triples=dataset.testing)

df_ep100 = pack_ep100.process(factory=dataset.training).df

df_ep100.nlargest(n=30, columns="score")
# Out:
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
#         head_id           head_label  relation_id relation_label  tail_id  \
# 214855    13774    Compound::DB00741            7            CrC    13659
# 27758     13439    Compound::DB00390            7            CrC    14109
# 195529    13491    Compound::DB00445            8            CtD    14788
# 101763    14784    Disease::DOID:219           14            DrD    14774
# 136918    13614    Compound::DB00578            7            CrC    14071
# 122879    13750    Compound::DB00717            7            CrC    13659
# 157352    14742  Disease::DOID:11934           14            DrD    14783
# 139022    14806   Disease::DOID:3953           14            DrD    14772
# 126803    13785    Compound::DB00752            7            CrC    13241
# 54739     14087    Compound::DB01069            7            CrC    13480
# 110787    14362    Compound::DB01420            7            CrC    14570
# 91115     13572    Compound::DB00535            7            CrC    14359
# 147585    14719  Disease::DOID:10283           10            DaG    31153
# 205908    13489    Compound::DB00443            7            CrC    13983
# 1067      14790    Disease::DOID:263           14            DrD    14756
# 19250     17113         Gene::128637           16            GcG    31251
# 75575     13467    Compound::DB00420            7            CrC    14430
# 47448     14845   Disease::DOID:9970           10            DaG    32344
# 218655    14419    Compound::DB01603            7            CrC    14079
# 109372    13626    Compound::DB00591            7            CrC    14035
# 179935    14768   Disease::DOID:1612           15            DuG    25172
# 33752     14723  Disease::DOID:10763           14            DrD    14845
# 82672     13864    Compound::DB00833            7            CrC    14359
# 37993     14178    Compound::DB01165            7            CrC    14152
# 115871    13967    Compound::DB00943            7            CrC    14271
# 197817    14727  Disease::DOID:10941           14            DrD    14803
# 187116    13608    Compound::DB00571            7            CrC    13254
# 115744    13902    Compound::DB00873            7            CrC    14146
# 102401    14439    Compound::DB01624            7            CrC    14236
# 184556    14757   Disease::DOID:1324           14            DrD    14772
#
#                  tail_label     score
# 214855    Compound::DB00624 -4.139701
# 27758     Compound::DB01092 -4.150275
# 195529   Disease::DOID:2531 -4.154389
# 101763   Disease::DOID:1793 -4.170156
# 136918    Compound::DB01053 -4.195703
# 122879    Compound::DB00624 -4.390118
# 157352   Disease::DOID:2174 -4.400328
# 139022   Disease::DOID:1781 -4.405519
# 126803    Compound::DB00182 -4.409390
# 54739     Compound::DB00433 -4.452825
# 110787    Compound::DB06710 -4.468347
# 91115     Compound::DB01416 -4.516587
# 147585            Gene::811 -4.518763
# 205908    Compound::DB00959 -4.543523
# 1067    Disease::DOID:13223 -4.565671
# 19250           Gene::81629 -4.582857
# 75575     Compound::DB01614 -4.594049
# 47448             Gene::857 -4.619582
# 218655    Compound::DB01061 -4.628133
# 109372    Compound::DB01013 -4.628389
# 179935          Gene::51155 -4.656793
# 33752    Disease::DOID:9970 -4.659617
# 82672     Compound::DB01416 -4.668001
# 37993     Compound::DB01137 -4.676787
# 115871    Compound::DB01262 -4.694947
# 197817   Disease::DOID:3565 -4.709812
# 187116    Compound::DB00195 -4.717469
# 115744    Compound::DB01130 -4.719170
# 102401    Compound::DB01224 -4.727707
# 184556   Disease::DOID:1781 -4.734806

# %%
triples_factory = dataset.training

# %%
# The relation Compound - treats - Disease
ctd_id = torch.as_tensor(triples_factory.relations_to_ids(["CtD"]))

ctd_id
# Out:
# tensor([8])

# %%
# Filter test triples to include only those with the "CtD" relation
test_triples = dataset.testing.mapped_triples
ctd_triples = test_triples[test_triples[:, 1] == ctd_id]

# %%
# Make predictions for the filtered triples
from pykeen.evaluation import RankBasedEvaluator
evaluator = RankBasedEvaluator()
metrics = evaluator.evaluate(model_ep100, mapped_triples=ctd_triples)
# Out:
# WARNING:pykeen.utils:The filtered setting was enabled, but there were no `additional_filter_triples`
# given. This means you probably forgot to pass (at least) the training triples. Try:
#
#     additional_filter_triples=[dataset.training.mapped_triples]
#
# Or if you want to use the Bordes et al. (2013) approach to filtering, do:
#
#     additional_filter_triples=[
#         dataset.training.mapped_triples,
#         dataset.validation.mapped_triples,
#     ]
#
# Evaluating on cuda:0: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 71.0/71.0 [00:00<00:00, 910triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.09s seconds

# %%
print_metrics(metrics)
# Out:
# MRR: 0.08314799517393112
# Hits@1: 0.02112676056338028
# Hits@3: 0.08450704225352113
# Hits@10: 0.2112676056338028

# %%
pack_ctd = predict_triples(model=model_ep100, triples=ctd_triples)

df_ctd = pack_ctd.process(factory=dataset.training).df

df_ctd.nlargest(n=30, columns="score")
# Out:
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
#     head_id         head_label  relation_id relation_label  tail_id  \
# 63    13491  Compound::DB00445            8            CtD    14788
# 26    13600  Compound::DB00563            8            CtD    14826
# 14    13654  Compound::DB00619            8            CtD    14788
# 3     14458  Compound::DB04572            8            CtD    14788
# 62    13487  Compound::DB00441            8            CtD    14757
# 24    14194  Compound::DB01181            8            CtD    14788
# 59    13607  Compound::DB00570            8            CtD    14757
# 52    13491  Compound::DB00445            8            CtD    14774
# 44    13882  Compound::DB00853            8            CtD    14755
# 66    13424  Compound::DB00373            8            CtD    14802
# 6     13468  Compound::DB00421            8            CtD    14723
# 40    13175  Compound::DB00091            8            CtD    14834
# 7     13795  Compound::DB00762            8            CtD    14784
# 8     13489  Compound::DB00443            8            CtD    14799
# 64    14019  Compound::DB00997            8            CtD    14772
# 49    14028  Compound::DB01006            8            CtD    14768
# 29    13774  Compound::DB00741            8            CtD    14791
# 53    13491  Compound::DB00445            8            CtD    14772
# 31    14005  Compound::DB00983            8            CtD    14791
# 2     13675  Compound::DB00641            8            CtD    14802
# 60    13969  Compound::DB00945            8            CtD    14802
# 38    14100  Compound::DB01083            8            CtD    14841
# 41    14458  Compound::DB04572            8            CtD    14768
# 28    13625  Compound::DB00590            8            CtD    14723
# 55    13254  Compound::DB00195            8            CtD    14769
# 27    13655  Compound::DB00620            8            CtD    14799
# 67    13491  Compound::DB00445            8            CtD    14805
# 16    14509  Compound::DB05812            8            CtD    14719
# 36    13633  Compound::DB00598            8            CtD    14723
# 23    14097  Compound::DB01080            8            CtD    14775
#
#              tail_label     score
# 63   Disease::DOID:2531 -4.154389
# 26   Disease::DOID:7148 -4.750464
# 14   Disease::DOID:2531 -4.788910
# 3    Disease::DOID:2531 -4.832768
# 62   Disease::DOID:1324 -4.902373
# 24   Disease::DOID:2531 -5.158857
# 59   Disease::DOID:1324 -5.213430
# 52   Disease::DOID:1793 -5.238699
# 44   Disease::DOID:1319 -5.285707
# 66   Disease::DOID:3393 -5.294956
# 6   Disease::DOID:10763 -5.367678
# 40   Disease::DOID:8893 -5.381073
# 7     Disease::DOID:219 -5.406860
# 8    Disease::DOID:3310 -5.421737
# 64   Disease::DOID:1781 -5.426111
# 49   Disease::DOID:1612 -5.430603
# 29   Disease::DOID:2841 -5.453227
# 53   Disease::DOID:1781 -5.472402
# 31   Disease::DOID:2841 -5.534736
# 2    Disease::DOID:3393 -5.549537
# 60   Disease::DOID:3393 -5.559003
# 38   Disease::DOID:9352 -5.610693
# 41   Disease::DOID:1612 -5.632743
# 28  Disease::DOID:10763 -5.665510
# 55   Disease::DOID:1686 -5.773543
# 27   Disease::DOID:3310 -5.837033
# 67    Disease::DOID:363 -5.860544
# 16  Disease::DOID:10283 -5.861987
# 36  Disease::DOID:10763 -5.866823
# 23   Disease::DOID:1826 -5.867910

# %%
id_to_entity = {v: k for k, v in dataset.entity_to_id.items()}

id_to_entity[13491]
# Out:
# 'Compound::DB00445'

# %%
import requests

# Define a cache dictionary for disease labels
disease_cache = {}

# Get disease label from by id from  Disease Ontology
def get_disease_label(disease_id):
    if disease_id.startswith("Disease::"):
        disease_id = disease_id.split("::")[1]

    # Check if the disease ID is already in the cache
    if disease_id in disease_cache:
        return disease_cache[disease_id]
    
    url = f"https://www.ebi.ac.uk/ols/api/ontologies/doid/terms?obo_id=DOID:{disease_id.split(':')[1]}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if 'label' in data['_embedded']['terms'][0]:
            label = data['_embedded']['terms'][0]['label']
            # Store the label in the cache
            disease_cache[disease_id] = label
            return label
    
    # If the request fails or the label is not found, return the ID itself
    disease_cache[disease_id] = disease_id
    return disease_id

# %%
import pandas as pd

def create_drug_mapping(file_path):
    # Read the TSV file into a pandas DataFrame
    df = pd.read_csv(file_path, sep='\t')

    # Create a dictionary from the DataFrame
    drug_mapping = dict(zip(df['drugbankId'], df['name']))

    return drug_mapping

# %%
def get_drug_label(drug_id, drug_mapping):
    # Remove the prefix if present
    if drug_id.startswith("Compound::"):
        drug_id = drug_id.split("::")[1]
    
    # Return the label if present, otherwise return the ID itself
    return drug_mapping.get(drug_id, drug_id)

# Example usage
file_path = 'drug-mappings.tsv'
drug_mapping = create_drug_mapping(file_path)

# %%
get_drug_label("Compound::DB00445", drug_mapping)
# Out:
# 'Epirubicin'

# %%
df_ctd_clean = pd.DataFrame(df_ctd)

# Replace DrugBank IDs with labels
df_ctd_clean['head_label'] = df_ctd_clean['head_label'].apply(lambda x: get_drug_label(x, drug_mapping))

# Replace Disease IDs with labels
df_ctd_clean['tail_label'] = df_ctd_clean['tail_label'].apply(get_disease_label)

# Drop the columns 'head_id', 'relation_id', 'tail_id'
df_ctd_clean = df_ctd_clean.drop(columns=['head_id', 'relation_id', 'tail_id'])

# Rename the columns for clarity
df_ctd_clean = df_ctd_clean.rename(columns={
    'head_label': 'Compound',
    'relation_label': 'Relation',
    'tail_label': 'Disease'
})

# Display the updated DataFrame
df_ctd_clean.nlargest(n=30, columns="score")
# Out:
#                 Compound Relation                   Disease     score
# 63            Epirubicin      CtD        hematologic cancer -4.154389
# 26          Methotrexate      CtD      rheumatoid arthritis -4.750464
# 14              Imatinib      CtD        hematologic cancer -4.788910
# 3               Thiotepa      CtD        hematologic cancer -4.832768
# 62           Gemcitabine      CtD               lung cancer -4.902373
# 24            Ifosfamide      CtD        hematologic cancer -5.158857
# 59           Vinblastine      CtD               lung cancer -5.213430
# 52            Epirubicin      CtD         pancreatic cancer -5.238699
# 44          Temozolomide      CtD              brain cancer -5.285707
# 66               Timolol      CtD   coronary artery disease -5.294956
# 6         Spironolactone      CtD              hypertension -5.367678
# 40          Cyclosporine      CtD                 psoriasis -5.381073
# 7             Irinotecan      CtD              colon cancer -5.406860
# 8          Betamethasone      CtD         atopic dermatitis -5.421737
# 64           Doxorubicin      CtD            thyroid cancer -5.426111
# 49             Letrozole      CtD             breast cancer -5.430603
# 29        Hydrocortisone      CtD                    asthma -5.453227
# 53            Epirubicin      CtD            thyroid cancer -5.472402
# 31            Formoterol      CtD                    asthma -5.534736
# 2            Simvastatin      CtD   coronary artery disease -5.549537
# 60  Acetylsalicylic acid      CtD   coronary artery disease -5.559003
# 38              Orlistat      CtD  type 2 diabetes mellitus -5.610693
# 41              Thiotepa      CtD             breast cancer -5.632743
# 28             Doxazosin      CtD              hypertension -5.665510
# 55             Betaxolol      CtD                  glaucoma -5.773543
# 27         Triamcinolone      CtD         atopic dermatitis -5.837033
# 67            Epirubicin      CtD            uterine cancer -5.860544
# 16           Abiraterone      CtD           prostate cancer -5.861987
# 36             Labetalol      CtD              hypertension -5.866823
# 23            Vigabatrin      CtD                  epilepsy -5.867910

# %%
run_config_best_hpo: dict = load_config('config/transe-best-hpo.yaml')

# %%
run_config_best_hpo
# Out:
# {'type': 'baseline',
#  'dataset': 'Hetionet',
#  'experiment_name': 'TransE best parameters',
#  'model': {'name': 'TransE', 'embedding_dim': 300},
#  'optimizer': {'class': 'Adagrad', 'lr': 0.02},
#  'train': {'loss_function': 'MarginRankingLoss',
#   'num_epoch': 500,
#   'num_negative': 61,
#   'create_inverse': False},
#  'save': {'path': 'results/baseline/transe_hetionet_best_hpo'},
#  'seed': 84}

# %%
result_best_hpo = run_baseline(run_config_best_hpo)

# %%
result_best_hpo
# Out:
# PipelineResult(random_seed=84, model=TransE(
#   (loss): MarginRankingLoss(
#     (margin_activation): ReLU()
#   )
#   (interaction): TransEInteraction()
#   (entity_representations): ModuleList(
#     (0): Embedding(
#       (_embeddings): Embedding(45158, 300)
#     )
#   )
#   (relation_representations): ModuleList(
#     (0): Embedding(
#       (_embeddings): Embedding(24, 300)
#     )
#   )
#   (weight_regularizers): ModuleList()
# ), training=TriplesFactory(num_entities=45158, num_relations=24, create_inverse_triples=False, num_triples=1800157, path="/home/david/.data/pykeen/datasets/hetionet/hetionet-v1.0-edges.sif.gz"), training_loop=<pykeen.training.slcwa.SLCWATrainingLoop object at 0x722587ce4380>, losses=[0.20368533536253564, 0.0979249069792461, 0.08039730824360601, 0.0702952014757013, 0.06372962425864462, 0.05921052526513091, 0.055881498103370134, 0.05343031228453226, 0.05128351813425926, 0.04956635025931698, 0.048323689740356716, 0.04724220059275949, 0.04611819865927948, 0.04524698816647751, 0.04442257381524293, 0.04382451229084567, 0.04304247321555681, 0.0425565199302965, 0.04202027091479927, 0.041356142723945576, 0.04092698972656331, 0.04057197011392712, 0.04020907721652801, 0.03973382551978481, 0.03952387946740479, 0.039154654048516736, 0.038837955480566476, 0.03849807719221133, 0.0383253153090379, 0.038112037371212576, 0.037722319392625145, 0.03749477582060826, 0.037315430370476244, 0.037086655724045646, 0.036920629673244366, 0.03671722205046382, 0.0365206302298324, 0.036326154199003986, 0.036156187488764216, 0.036061346037970246, 0.0358927064936553, 0.035710843438091895, 0.0355510874304378, 0.0354202861226968, 0.035246772418779757, 0.035110674634791984, 0.03497442165898229, 0.034884316693626946, 0.0347307435784116, 0.034702648762857224, 0.034544803171690903, 0.03446094327038355, 0.03428278918392889, 0.03425130155361316, 0.03415155204821407, 0.03407434160785116, 0.033913163518569135, 0.03381554528157543, 0.03368652986857375, 0.03367981373224369], metric_results=<pykeen.evaluation.rank_based_evaluator.RankBasedMetricResults object at 0x722577d917c0>, train_seconds=8688.69645857811, evaluate_seconds=479.59317421913147, stopper=EarlyStopper(evaluator=<pykeen.evaluation.rank_based_evaluator.RankBasedEvaluator object at 0x722577dfb380>, training_triples_factory=TriplesFactory(num_entities=45158, num_relations=24, create_inverse_triples=False, num_triples=1800157, path="/home/david/.data/pykeen/datasets/hetionet/hetionet-v1.0-edges.sif.gz"), evaluation_triples_factory=TriplesFactory(num_entities=45158, num_relations=24, create_inverse_triples=False, num_triples=225020, path="/home/david/.data/pykeen/datasets/hetionet/hetionet-v1.0-edges.sif.gz"), evaluation_batch_size=None, evaluation_slice_size=None, frequency=10, patience=2, metric='hits_at_k', relative_delta=0.01, larger_is_better=True, result_tracker=<pykeen.trackers.base.MultiResultTracker object at 0x72256ee9f290>, stopped=True, best_model_path=PosixPath('/home/david/.data/pykeen/checkpoints/best-model-weights-fd27d17f-b3ac-47bc-be80-6de76897ac3d.pt'), clean_up_checkpoint=True), configuration={'dataset': 'hetionet', 'dataset_kwargs': {'random_state': 84, 'create_inverse_triples': False}, 'model': 'TransE', 'model_kwargs': {'embedding_dim': 300, 'random_seed': 84, 'loss': MarginRankingLoss(
#   (margin_activation): ReLU()
# ), 'scoring_fct_norm': 1, 'entity_initializer': <function xavier_uniform_ at 0x7225b19dc040>, 'entity_constrainer': <function normalize at 0x72267dd8e020>, 'relation_initializer': <pykeen.utils.compose object at 0x7225b23e66c0>, 'relation_constrainer': None, 'regularizer': None, 'regularizer_kwargs': None}, 'loss_kwargs': None, 'regularizer_kwargs': None, 'optimizer': 'Adagrad', 'optimizer_kwargs': {'lr': 0.02, 'lr_decay': 0, 'eps': 1e-10, 'weight_decay': 0, 'initial_accumulator_value': 0, 'foreach': None, 'maximize': False, 'differentiable': False}, 'training_loop': 'SLCWATrainingLoop', 'training_loop_kwargs': {'negative_sampler_kwargs': {'num_negs_per_pos': 61}}, 'evaluator': 'RankBasedEvaluator', 'evaluator_kwargs': {'filtered': True}, 'num_epochs': 500, 'batch_size': 256, 'evaluation_kwargs': {'additional_filter_triples': {'training': {'sha512': 'c994ec770ffe11ba74635a8b1531e3a30ce01569dd72a30b128f5a3b70ec7704e64a7b0328261bdf83f6bc72e6f041e2b2800c99d533ae6d30b7b82b146948fc'}}}}, metadata={}, version='1.10.2', git_hash='UNHASHED')

# %%
print_metrics(result_best_hpo.metric_results)
# Out:
# MRR: 0.07458487898111343
# Hits@1: 0.014005421740289752
# Hits@3: 0.08435472402453115
# Hits@10: 0.1997289129855124

# %%
metrics_best_hpo = evaluator.evaluate(result_best_hpo.model, mapped_triples=ctd_triples)
# Out:
# WARNING:pykeen.utils:The filtered setting was enabled, but there were no `additional_filter_triples`
# given. This means you probably forgot to pass (at least) the training triples. Try:
#
#     additional_filter_triples=[dataset.training.mapped_triples]
#
# Or if you want to use the Bordes et al. (2013) approach to filtering, do:
#
#     additional_filter_triples=[
#         dataset.training.mapped_triples,
#         dataset.validation.mapped_triples,
#     ]
#
# Evaluating on cuda:0: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 71.0/71.0 [00:00<00:00, 471triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.17s seconds

# %%
print_metrics(metrics_best_hpo)
# Out:
# MRR: 0.10783362388610841
# Hits@1: 0.0
# Hits@3: 0.1056338028169014
# Hits@10: 0.30985915492957744

# %%
run_config_best_hpo2: dict = load_config('config/transe-best-hpo2.yaml')

# %%
run_config_best_hpo2
# Out:
# {'type': 'baseline',
#  'dataset': 'Hetionet',
#  'experiment_name': 'TransE best parameters Early stopper 0.002',
#  'model': {'name': 'TransE', 'embedding_dim': 300},
#  'optimizer': {'class': 'Adagrad', 'lr': 0.02},
#  'train': {'loss_function': 'MarginRankingLoss',
#   'num_epoch': 500,
#   'num_negative': 61,
#   'create_inverse': False},
#  'save': {'path': 'results/baseline/transe_hetionet_best_hpo2'},
#  'seed': 84}

# %%
result_best_hpo2 = run_baseline(run_config_best_hpo2)

# %%
print_metrics(result_best_hpo2.metric_results)
# Out:
# MRR: 0.07222168147563934
# Hits@1: 0.009085859034752466
# Hits@3: 0.08287485556839393
# Hits@10: 0.2029019642698427

# %%
# Make predictions on test for best_hpo2 model

metrics = evaluator.evaluate(result_best_hpo2.model, mapped_triples=dataset.testing.mapped_triples)
# Out:
# WARNING:pykeen.utils:The filtered setting was enabled, but there were no `additional_filter_triples`
# given. This means you probably forgot to pass (at least) the training triples. Try:
#
#     additional_filter_triples=[dataset.training.mapped_triples]
#
# Or if you want to use the Bordes et al. (2013) approach to filtering, do:
#
#     additional_filter_triples=[
#         dataset.training.mapped_triples,
#         dataset.validation.mapped_triples,
#     ]
#
# Evaluating on cuda:0: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 225k/225k [05:15<00:00, 712triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 316.19s seconds

# %%
print_metrics(metrics)
# Out:
# MRR: 0.06745758652687073
# Hits@1: 0.007819304950671051
# Hits@3: 0.06488089947560217
# Hits@10: 0.1891631854946227

# %%
pack_best_hpo2 = predict_all(model=result_best_hpo2.model, k=100000)
# Out:
# WARNING:pykeen.predict:predict is an expensive operation, involving 48,941,879,136 score evaluations.

# %%
pred_best_hpo2 = pack_best_hpo2.process(factory=dataset.training)
# Out:
# 100000

# %%
len(pred_best_hpo2.df)
# Out:
# 100000

# %%
pred_best_hpo2_add_training = pred_best_hpo2.add_membership_columns(training=result.training)

# %%
pred_best_hpo2_add_training_df = pred_best_hpo2_add_training.df
len(pred_best_hpo2_add_training_df)
# Out:
# 100000

# %%
# Remove rows where head_id and tail_id are the same
pred_best_hpo2_add_training_filtered = pred_best_hpo2_add_training_df[pred_best_hpo2_add_training_df['head_id'] != pred_best_hpo2_add_training_df['tail_id']]

# %%
pred_best_hpo2_add_training_filtered
# Out:
#        head_id                      head_label  relation_id relation_label  \
# 90316    35393  Molecular Function::GO:0016462           14            DrD
# 90317     7288  Biological Process::GO:0048858           14            DrD
# 90318    12021  Cellular Component::GO:0005789           14            DrD
# 90319     7793  Biological Process::GO:0051707           14            DrD
# 90320    35510  Molecular Function::GO:0016818            7            CrC
# ...        ...                             ...          ...            ...
# 91558     3288  Biological Process::GO:0016567            7            CrC
# 91559     1836  Biological Process::GO:0006812            7            CrC
# 91560    34169  Molecular Function::GO:0003690           14            DrD
# 91561     7755  Biological Process::GO:0051603           14            DrD
# 91562    13491               Compound::DB00445            7            CrC
#
#        tail_id                      tail_label      score  in_training
# 90316    35510  Molecular Function::GO:0016818  -9.249692        False
# 90317     4703  Biological Process::GO:0032990  -9.353173        False
# 90318    12669  Cellular Component::GO:0042175  -9.567289        False
# 90319     2510  Biological Process::GO:0009607  -9.605646        False
# 90320    35393  Molecular Function::GO:0016462  -9.608790        False
# ...        ...                             ...        ...          ...
# 91558     8883  Biological Process::GO:0070647 -12.337824        False
# 91559     3834  Biological Process::GO:0030001 -12.339102        False
# 91560    36870  Molecular Function::GO:1990837 -12.339445        False
# 91561     6120  Biological Process::GO:0043632 -12.339492        False
# 91562    14019               Compound::DB00997 -12.340623        False
#
# [1247 rows x 8 columns]

# %%
pred_best_hpo2_add_training_filtered.nlargest(n=30, columns="score")
# Out:
#        head_id                      head_label  relation_id relation_label  \
# 90316    35393  Molecular Function::GO:0016462           14            DrD
# 90317     7288  Biological Process::GO:0048858           14            DrD
# 90318    12021  Cellular Component::GO:0005789           14            DrD
# 90319     7793  Biological Process::GO:0051707           14            DrD
# 90320    35510  Molecular Function::GO:0016818            7            CrC
# 90321     2510  Biological Process::GO:0009607            7            CrC
# 90322      250         Anatomy::UBERON:0001895           14            DrD
# 90323      274         Anatomy::UBERON:0002028           14            DrD
# 90324      250         Anatomy::UBERON:0001895           14            DrD
# 90325     2101  Biological Process::GO:0007283           14            DrD
# 90326    35510  Molecular Function::GO:0016818           14            DrD
# 90327    35393  Molecular Function::GO:0016462           14            DrD
# 90328    35510  Molecular Function::GO:0016818           14            DrD
# 90329      274         Anatomy::UBERON:0002028           14            DrD
# 90330     7793  Biological Process::GO:0051707           14            DrD
# 90331      320         Anatomy::UBERON:0002298           14            DrD
# 90332     7288  Biological Process::GO:0048858            7            CrC
# 90333     2510  Biological Process::GO:0009607           14            DrD
# 90334     3573  Biological Process::GO:0019953           14            DrD
# 90335    35510  Molecular Function::GO:0016818           14            DrD
# 90336     4703  Biological Process::GO:0032990           14            DrD
# 90337      250         Anatomy::UBERON:0001895            7            CrC
# 90338     6261  Biological Process::GO:0044419           14            DrD
# 90339    35393  Molecular Function::GO:0016462           14            DrD
# 90340     5912  Biological Process::GO:0043069           14            DrD
# 90341    35393  Molecular Function::GO:0016462            7            CrC
# 90342    12669  Cellular Component::GO:0042175           14            DrD
# 90343      320         Anatomy::UBERON:0002298           14            DrD
# 90344     3269  Biological Process::GO:0016477           14            DrD
# 90345     7182  Biological Process::GO:0048609           14            DrD
#
#        tail_id                      tail_label      score  in_training
# 90316    35510  Molecular Function::GO:0016818  -9.249692        False
# 90317     4703  Biological Process::GO:0032990  -9.353173        False
# 90318    12669  Cellular Component::GO:0042175  -9.567289        False
# 90319     2510  Biological Process::GO:0009607  -9.605646        False
# 90320    35393  Molecular Function::GO:0016462  -9.608790        False
# 90321     7793  Biological Process::GO:0051707  -9.609782        False
# 90322      274         Anatomy::UBERON:0002028  -9.616606        False
# 90323      250         Anatomy::UBERON:0001895  -9.666279        False
# 90324      320         Anatomy::UBERON:0002298  -9.675369        False
# 90325     7073  Biological Process::GO:0048232  -9.736124        False
# 90326    35393  Molecular Function::GO:0016462  -9.747831        False
# 90327    35604  Molecular Function::GO:0017111  -9.749484        False
# 90328    35509  Molecular Function::GO:0016817  -9.764088        False
# 90329      320         Anatomy::UBERON:0002298  -9.814556        False
# 90330     5953  Biological Process::GO:0043207  -9.821548        False
# 90331      250         Anatomy::UBERON:0001895  -9.837687        False
# 90332     4703  Biological Process::GO:0032990  -9.868441        False
# 90333     7793  Biological Process::GO:0051707  -9.869799        False
# 90334     2099  Biological Process::GO:0007276  -9.870377        False
# 90335    35604  Molecular Function::GO:0017111  -9.896002        False
# 90336     7288  Biological Process::GO:0048858  -9.897465        False
# 90337      320         Anatomy::UBERON:0002298  -9.910485        False
# 90338     3189  Biological Process::GO:0016032  -9.911998        False
# 90339    35509  Molecular Function::GO:0016817  -9.925205        False
# 90340     5910  Biological Process::GO:0043066  -9.929808        False
# 90341    35510  Molecular Function::GO:0016818  -9.952419        False
# 90342    12021  Cellular Component::GO:0005789  -9.954401        False
# 90343      274         Anatomy::UBERON:0002028  -9.979525        False
# 90344     7296  Biological Process::GO:0048870 -10.008942        False
# 90345     4487  Biological Process::GO:0032504 -10.019699        False

# %%
pred_best_hpo2_add_training_filtered.groupby(['relation_label']).size()
# Out:
# relation_label
# CrC    466
# DrD    781
# dtype: int64

# %%
dataset.validation
# Out:
# TriplesFactory(num_entities=45158, num_relations=24, create_inverse_triples=False, num_triples=225020, path="/home/david/.data/pykeen/datasets/hetionet/hetionet-v1.0-edges.sif.gz")

# %%
from pykeen import predict
compound_treats_arthritis = predict.predict_target(
    model=best_hpo_model,
    relation="CtD",
    tail="Disease::DOID:7148",
    triples_factory=dataset.training,
)

# %%
compound_treats_arthritis_df = compound_treats_arthritis.df

# %%
compound_treats_arthritis_df
# Out:
#        head_id      score             head_label
# 14826    14826 -18.055531     Disease::DOID:7148
# 13826    13826 -18.602427      Compound::DB00795
# 13889    13889 -18.843971      Compound::DB00860
# 13198    13198 -18.893045      Compound::DB00136
# 13670    13670 -18.908836      Compound::DB00635
# ...        ...        ...                    ...
# 39556    39556 -27.169384  Side Effect::C0015397
# 44648    44648 -27.176758  Side Effect::C2830004
# 44523    44523 -27.192657  Side Effect::C1868771
# 42407    42407 -27.231775  Side Effect::C0392197
# 42591    42591 -27.288671  Side Effect::C0438215
#
# [45158 rows x 3 columns]

# %%
compound_treats_arthritis_df_filtered = compound_treats_arthritis_df[compound_treats_arthritis_df['head_label'].str.contains("Compound")]

# %%
compound_treats_arthritis_df_filtered
# Out:
#        head_id      score         head_label
# 13826    13826 -18.602427  Compound::DB00795
# 13889    13889 -18.843971  Compound::DB00860
# 13198    13198 -18.893045  Compound::DB00136
# 13670    13670 -18.908836  Compound::DB00635
# 13447    13447 -18.920061  Compound::DB00398
# ...        ...        ...                ...
# 14365    14365 -24.540871  Compound::DB01423
# 14283    14283 -24.611282  Compound::DB01288
# 14428    14428 -24.784145  Compound::DB01612
# 14686    14686 -24.802370  Compound::DB08979
# 13498    13498 -25.249691  Compound::DB00453
#
# [1538 rows x 3 columns]

# %%
import pandas as pd
compound_treats_arthritis = pd.DataFrame(compound_treats_arthritis_df_filtered)
# Replace DrugBank IDs with labels
compound_treats_arthritis['head_label'] = compound_treats_arthritis['head_label'].apply(lambda x: get_drug_label(x, drug_mapping))

# %% [markdown]
# compound_treats_arthritis

# %%
compound_treats_arthritis.nlargest(n=10, columns="score")
# Out:
#        head_id      score     head_label
# 13826    13826 -18.602427  Sulfasalazine
# 13889    13889 -18.843971   Prednisolone
# 13198    13198 -18.893045     Calcitriol
# 13670    13670 -18.908836     Prednisone
# 13447    13447 -18.920061      Sorafenib
# 13175    13175 -19.030796   Cyclosporine
# 14245    14245 -19.051506  Dexamethasone
# 13805    13805 -19.130682      Etoposide
# 14662    14662 -19.137554     Dabrafenib
# 13600    13600 -19.251726   Methotrexate

# %%
compound_treats_arthritis.to_csv('transe-top-10-arthritis.csv', index=False)

# %%
evaluation_relation_whitelist = {'CtD'}

# %%
ctd_config: dict = load_config('config/transe-only-ctd-relation.yaml')
ctd_config
# Out:
# {'type': 'baseline',
#  'dataset': 'Hetionet',
#  'experiment_name': 'TransE trained optimizing only Compound Treats Disease',
#  'model': {'name': 'TransE', 'embedding_dim': 300},
#  'optimizer': {'class': 'Adagrad', 'lr': 0.02},
#  'train': {'loss_function': 'MarginRankingLoss',
#   'num_epoch': 500,
#   'num_negative': 61,
#   'create_inverse': False,
#   'evaluation_relation_whitelist': ['CtD']},
#  'save': {'path': 'results/baseline/transe_hetionet_only_ctd_relation'},
#  'seed': 84}

# %%
set(ctd_config['train']['evaluation_relation_whitelist'])
# Out:
# {'CtD'}

# %%
result_ctd = run_baseline(ctd_config)

# %%
print_metrics(result_ctd.metric_results)
# Out:
# MRR: 0.0709473192691803
# Hits@1: 0.0
# Hits@3: 0.0625
# Hits@10: 0.19444444444444445

# %%
dataset.training
# Out:
# TriplesFactory(num_entities=45158, num_relations=24, create_inverse_triples=False, num_triples=1800157, path="/home/david/.data/pykeen/datasets/hetionet/hetionet-v1.0-edges.sif.gz")

# %%
# Run model with config from checkpoint
def run_pipeline(config: dict, checkpoint_name):

    pipeline_result = pipeline(
        dataset=config["dataset"],
        dataset_kwargs={
            "random_state": config["seed"],
            "create_inverse_triples": config["train"]["create_inverse"],
        },
        model=config["model"]["name"],
        model_kwargs={
            "embedding_dim": config["model"]["embedding_dim"],
            "random_seed": config["seed"],
        },
        training_loop="sLCWA",
        training_kwargs={
            "num_epochs": config["train"]["num_epoch"],
            "checkpoint_name": checkpoint_name
        },
        optimizer=config["optimizer"]["class"],
        optimizer_kwargs={"lr": config["optimizer"]["lr"]},
        negative_sampler_kwargs={
            "num_negs_per_pos": config["train"]["num_negative"],
        },
        stopper='early',
        stopper_kwargs=dict(frequency=10, patience=3, relative_delta=0.002),
        random_seed=config["seed"],
        evaluator_kwargs={"filtered": True},
        use_testing_data=False,
        result_tracker='mlflow',
        result_tracker_kwargs=dict(
        tracking_uri='http://localhost:5000',
        experiment_name=config["experiment_name"],
    ),
    )
    
    pipeline_result.save_to_directory(config["save"]["path"])
    return pipeline_result

# %%
import torch
best_hpo_model = torch.load('results/baseline/transe_hetionet_best_hpo2/trained_model.pkl')

# %%
# Make predictions on the test triples
from pykeen.evaluation import RankBasedEvaluator
evaluator = RankBasedEvaluator()
metrics_testing = evaluator.evaluate(best_hpo_model, mapped_triples=dataset.testing.mapped_triples)
# Out:
# The filtered setting was enabled, but there were no `additional_filter_triples`
# given. This means you probably forgot to pass (at least) the training triples. Try:
#
#     additional_filter_triples=[dataset.training.mapped_triples]
#
# Or if you want to use the Bordes et al. (2013) approach to filtering, do:
#
#     additional_filter_triples=[
#         dataset.training.mapped_triples,
#         dataset.validation.mapped_triples,
#     ]
#
# Evaluating on cuda:0: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 225k/225k [05:46<00:00, 650triple/s]

# %%
print_metrics(metrics_testing)
# Out:
# MRR: 0.06745758652687073
# Hits@1: 0.007819304950671051
# Hits@3: 0.06488089947560217
# Hits@10: 0.1891631854946227

# %%
# Let's predict the top 100k predictions
from pykeen.predict import predict_all
pack_top_100k = predict_all(model=best_hpo_model, k=100000)
# Out:
# predict is an expensive operation, involving 48,941,879,136 score evaluations.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 4
#       2 from pykeen.predict import predict_all
#       3 pack_top_100k = predict_all(model=best_hpo_model, k=100000)
# ----> 4 predictions_top_100k = best_hpo_model.process(factory=dataset.training)
#
# File ~/Repos/FMI/SW-LinkPrediction/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1709, in Module.__getattr__(self, name)
#    1707     if name in modules:
#    1708         return modules[name]
# -> 1709 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'TransE' object has no attribute 'process'

# %%
predictions_top_100k = pack_top_100k.process(factory=dataset.training)

# %%
predictions_top_100k.df.nlargest(n=50, columns="score")
# Out:
#     head_id                      head_label  relation_id relation_label  \
# 0       595  Biological Process::GO:0001579           14            DrD
# 1     10767  Biological Process::GO:1903034           14            DrD
# 2     14708               Compound::DB09020           14            DrD
# 3     14983                 Gene::100287178           14            DrD
# 4     17412                      Gene::1376           14            DrD
# 5     17726                      Gene::1456           14            DrD
# 6     22560                    Gene::338442           14            DrD
# 7     25641                      Gene::5207           14            DrD
# 8     25815                     Gene::53822           14            DrD
# 9     26044                     Gene::54596           14            DrD
# 10    27697                     Gene::57553           14            DrD
# 11    28720                    Gene::643596           14            DrD
# 12    29740                      Gene::7159           14            DrD
# 13    29836                    Gene::728036           14            DrD
# 14    30887                     Gene::80019           14            DrD
# 15    31622                     Gene::83988           14            DrD
# 16    31927                     Gene::84547           14            DrD
# 17    32567                      Gene::8836           14            DrD
# 18    32586                      Gene::8857           14            DrD
# 19    38418          Pathway::WP1425_r74390           14            DrD
# 20    41816           Side Effect::C0239819           14            DrD
# 21    42843           Side Effect::C0542184           14            DrD
# 22    42957           Side Effect::C0553713           14            DrD
# 23        6         Anatomy::UBERON:0000013           14            DrD
# 24       11         Anatomy::UBERON:0000038           14            DrD
# 25       12         Anatomy::UBERON:0000042           14            DrD
# 26       18         Anatomy::UBERON:0000057           14            DrD
# 27       20         Anatomy::UBERON:0000178           14            DrD
# 28       24         Anatomy::UBERON:0000482           14            DrD
# 29       25         Anatomy::UBERON:0000483           14            DrD
# 30       28         Anatomy::UBERON:0000946           14            DrD
# 31       49         Anatomy::UBERON:0000997           14            DrD
# 32       57         Anatomy::UBERON:0001011           14            DrD
# 33       61         Anatomy::UBERON:0001021           14            DrD
# 34       75         Anatomy::UBERON:0001111           14            DrD
# 35       80         Anatomy::UBERON:0001143           14            DrD
# 36       83         Anatomy::UBERON:0001175           14            DrD
# 37       86         Anatomy::UBERON:0001184           14            DrD
# 38       87         Anatomy::UBERON:0001193           14            DrD
# 39       94         Anatomy::UBERON:0001235           14            DrD
# 40      107         Anatomy::UBERON:0001322           14            DrD
# 41      110         Anatomy::UBERON:0001343           14            DrD
# 42      121         Anatomy::UBERON:0001460           14            DrD
# 43      122         Anatomy::UBERON:0001461           14            DrD
# 44      123         Anatomy::UBERON:0001463           14            DrD
# 45      131         Anatomy::UBERON:0001485           14            DrD
# 46      134         Anatomy::UBERON:0001490           14            DrD
# 47      147         Anatomy::UBERON:0001579           14            DrD
# 48      165         Anatomy::UBERON:0001643           14            DrD
# 49      174         Anatomy::UBERON:0001675           14            DrD
#
#     tail_id                      tail_label     score
# 0       595  Biological Process::GO:0001579 -7.733004
# 1     10767  Biological Process::GO:1903034 -7.733004
# 2     14708               Compound::DB09020 -7.733004
# 3     14983                 Gene::100287178 -7.733004
# 4     17412                      Gene::1376 -7.733004
# 5     17726                      Gene::1456 -7.733004
# 6     22560                    Gene::338442 -7.733004
# 7     25641                      Gene::5207 -7.733004
# 8     25815                     Gene::53822 -7.733004
# 9     26044                     Gene::54596 -7.733004
# 10    27697                     Gene::57553 -7.733004
# 11    28720                    Gene::643596 -7.733004
# 12    29740                      Gene::7159 -7.733004
# 13    29836                    Gene::728036 -7.733004
# 14    30887                     Gene::80019 -7.733004
# 15    31622                     Gene::83988 -7.733004
# 16    31927                     Gene::84547 -7.733004
# 17    32567                      Gene::8836 -7.733004
# 18    32586                      Gene::8857 -7.733004
# 19    38418          Pathway::WP1425_r74390 -7.733004
# 20    41816           Side Effect::C0239819 -7.733004
# 21    42843           Side Effect::C0542184 -7.733004
# 22    42957           Side Effect::C0553713 -7.733004
# 23        6         Anatomy::UBERON:0000013 -7.733004
# 24       11         Anatomy::UBERON:0000038 -7.733004
# 25       12         Anatomy::UBERON:0000042 -7.733004
# 26       18         Anatomy::UBERON:0000057 -7.733004
# 27       20         Anatomy::UBERON:0000178 -7.733004
# 28       24         Anatomy::UBERON:0000482 -7.733004
# 29       25         Anatomy::UBERON:0000483 -7.733004
# 30       28         Anatomy::UBERON:0000946 -7.733004
# 31       49         Anatomy::UBERON:0000997 -7.733004
# 32       57         Anatomy::UBERON:0001011 -7.733004
# 33       61         Anatomy::UBERON:0001021 -7.733004
# 34       75         Anatomy::UBERON:0001111 -7.733004
# 35       80         Anatomy::UBERON:0001143 -7.733004
# 36       83         Anatomy::UBERON:0001175 -7.733004
# 37       86         Anatomy::UBERON:0001184 -7.733004
# 38       87         Anatomy::UBERON:0001193 -7.733004
# 39       94         Anatomy::UBERON:0001235 -7.733004
# 40      107         Anatomy::UBERON:0001322 -7.733004
# 41      110         Anatomy::UBERON:0001343 -7.733004
# 42      121         Anatomy::UBERON:0001460 -7.733004
# 43      122         Anatomy::UBERON:0001461 -7.733004
# 44      123         Anatomy::UBERON:0001463 -7.733004
# 45      131         Anatomy::UBERON:0001485 -7.733004
# 46      134         Anatomy::UBERON:0001490 -7.733004
# 47      147         Anatomy::UBERON:0001579 -7.733004
# 48      165         Anatomy::UBERON:0001643 -7.733004
# 49      174         Anatomy::UBERON:0001675 -7.733004

# %%
# Let's filter the triples from the train dataset

predictions_top_100k_filtered = predictions_top_100k.filter_triples(dataset.training)

# %%
len(predictions_top_100k_filtered.df)
# Out:
# 99999

# %%
predictions_top_100k_filtered_df = predictions_top_100k_filtered.df

# %%
# Remove rows where head_id and tail_id are the same (reflexive)
predictions_top_100k_filtered_no_reflexive= predictions_top_100k_filtered_df[predictions_top_100k_filtered_df['head_id'] != predictions_top_100k_filtered_df['tail_id']]

# %%
predictions_top_100k_filtered_no_reflexive
# Out:
#        head_id                      head_label  relation_id relation_label  \
# 90316    35393  Molecular Function::GO:0016462           14            DrD
# 90317     7288  Biological Process::GO:0048858           14            DrD
# 90318    12021  Cellular Component::GO:0005789           14            DrD
# 90319     7793  Biological Process::GO:0051707           14            DrD
# 90320    35510  Molecular Function::GO:0016818            7            CrC
# ...        ...                             ...          ...            ...
# 91558     3288  Biological Process::GO:0016567            7            CrC
# 91559     1836  Biological Process::GO:0006812            7            CrC
# 91560    34169  Molecular Function::GO:0003690           14            DrD
# 91561     7755  Biological Process::GO:0051603           14            DrD
# 91562    13491               Compound::DB00445            7            CrC
#
#        tail_id                      tail_label      score
# 90316    35510  Molecular Function::GO:0016818  -9.249692
# 90317     4703  Biological Process::GO:0032990  -9.353173
# 90318    12669  Cellular Component::GO:0042175  -9.567289
# 90319     2510  Biological Process::GO:0009607  -9.605646
# 90320    35393  Molecular Function::GO:0016462  -9.608790
# ...        ...                             ...        ...
# 91558     8883  Biological Process::GO:0070647 -12.337824
# 91559     3834  Biological Process::GO:0030001 -12.339102
# 91560    36870  Molecular Function::GO:1990837 -12.339445
# 91561     6120  Biological Process::GO:0043632 -12.339492
# 91562    14019               Compound::DB00997 -12.340623
#
# [1246 rows x 7 columns]

# %%
top30_filtered = predictions_top_100k_filtered_no_reflexive.nlargest(n=30, columns="score")

# %%
top30_filtered = top30_filtered.drop(['head_id', 'relation_id', 'tail_id'], axis=1)

# %%
top30_filtered
# Out:
#                            head_label relation_label  \
# 90316  Molecular Function::GO:0016462            DrD
# 90317  Biological Process::GO:0048858            DrD
# 90318  Cellular Component::GO:0005789            DrD
# 90319  Biological Process::GO:0051707            DrD
# 90320  Molecular Function::GO:0016818            CrC
# 90321  Biological Process::GO:0009607            CrC
# 90322         Anatomy::UBERON:0001895            DrD
# 90323         Anatomy::UBERON:0002028            DrD
# 90324         Anatomy::UBERON:0001895            DrD
# 90325  Biological Process::GO:0007283            DrD
# 90326  Molecular Function::GO:0016818            DrD
# 90327  Molecular Function::GO:0016462            DrD
# 90328  Molecular Function::GO:0016818            DrD
# 90329         Anatomy::UBERON:0002028            DrD
# 90330  Biological Process::GO:0051707            DrD
# 90331         Anatomy::UBERON:0002298            DrD
# 90332  Biological Process::GO:0048858            CrC
# 90333  Biological Process::GO:0009607            DrD
# 90334  Biological Process::GO:0019953            DrD
# 90335  Molecular Function::GO:0016818            DrD
# 90336  Biological Process::GO:0032990            DrD
# 90337         Anatomy::UBERON:0001895            CrC
# 90338  Biological Process::GO:0044419            DrD
# 90339  Molecular Function::GO:0016462            DrD
# 90340  Biological Process::GO:0043069            DrD
# 90341  Molecular Function::GO:0016462            CrC
# 90342  Cellular Component::GO:0042175            DrD
# 90343         Anatomy::UBERON:0002298            DrD
# 90344  Biological Process::GO:0016477            DrD
# 90345  Biological Process::GO:0048609            DrD
#
#                            tail_label      score
# 90316  Molecular Function::GO:0016818  -9.249692
# 90317  Biological Process::GO:0032990  -9.353173
# 90318  Cellular Component::GO:0042175  -9.567289
# 90319  Biological Process::GO:0009607  -9.605646
# 90320  Molecular Function::GO:0016462  -9.608790
# 90321  Biological Process::GO:0051707  -9.609782
# 90322         Anatomy::UBERON:0002028  -9.616606
# 90323         Anatomy::UBERON:0001895  -9.666279
# 90324         Anatomy::UBERON:0002298  -9.675369
# 90325  Biological Process::GO:0048232  -9.736124
# 90326  Molecular Function::GO:0016462  -9.747831
# 90327  Molecular Function::GO:0017111  -9.749484
# 90328  Molecular Function::GO:0016817  -9.764088
# 90329         Anatomy::UBERON:0002298  -9.814556
# 90330  Biological Process::GO:0043207  -9.821548
# 90331         Anatomy::UBERON:0001895  -9.837687
# 90332  Biological Process::GO:0032990  -9.868441
# 90333  Biological Process::GO:0051707  -9.869799
# 90334  Biological Process::GO:0007276  -9.870377
# 90335  Molecular Function::GO:0017111  -9.896002
# 90336  Biological Process::GO:0048858  -9.897465
# 90337         Anatomy::UBERON:0002298  -9.910485
# 90338  Biological Process::GO:0016032  -9.911998
# 90339  Molecular Function::GO:0016817  -9.925205
# 90340  Biological Process::GO:0043066  -9.929808
# 90341  Molecular Function::GO:0016818  -9.952419
# 90342  Cellular Component::GO:0005789  -9.954401
# 90343         Anatomy::UBERON:0002028  -9.979525
# 90344  Biological Process::GO:0048870 -10.008942
# 90345  Biological Process::GO:0032504 -10.019699

# %%
top30_filtered.to_csv('transe-top-30-global.csv', index=False)
